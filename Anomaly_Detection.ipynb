# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Importing necessary libraries and reading dataset
# #### Dataset can be downloaded from https://www.kaggle.com/nphantawee/pump-sensor-data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("sensor.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 220315      220315  2018-08-31 23:55:00   2.407350   47.69965  50.520830
# 220316      220316  2018-08-31 23:56:00   2.400463   47.69965  50.564240
# 220317      220317  2018-08-31 23:57:00   2.396528   47.69965  50.520830
# 220318      220318  2018-08-31 23:58:00   2.406366   47.69965  50.520832
# 220319      220319  2018-08-31 23:59:00   2.396528   47.69965  50.520832
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# 220315  43.142361  634.722229   64.59095   15.11863   16.65220  ...
# 220316  43.142361  630.902771   65.83363   15.15480   16.70284  ...
# 220317  43.142361  625.925903   67.29445   15.08970   16.70284  ...
# 220318  43.142361  635.648100   65.09175   15.11863   16.56539  ...
# 220319  43.142361  639.814800   65.45634   15.11863   16.65220  ...
#
#         sensor_43  sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  \
# ...

# %%
df.drop('Unnamed: 0',axis=True, inplace=True)

# %%
df.machine_status.value_counts()
# Out:
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: machine_status, dtype: int64

# %% [markdown]
# ### Observing datatype of features and convering to require datatype.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 54 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   timestamp       220320 non-null  object
#  1   sensor_00       210112 non-null  float64
#  2   sensor_01       219951 non-null  float64
#  3   sensor_02       220301 non-null  float64
#  4   sensor_03       220301 non-null  float64
#  5   sensor_04       220301 non-null  float64
#  6   sensor_05       220301 non-null  float64
#  7   sensor_06       215522 non-null  float64
#  8   sensor_07       214869 non-null  float64
#  9   sensor_08       215213 non-null  float64
#  10  sensor_09       215725 non-null  float64
#  11  sensor_10       220301 non-null  float64
#  12  sensor_11       220301 non-null  float64
#  13  sensor_12       220301 non-null  float64
#  14  sensor_13       220301 non-null  float64
#  15  sensor_14       220299 non-null  float64
# ...

# %%
df['timestamp']=pd.to_datetime(df['timestamp'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 54 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   timestamp       220320 non-null  datetime64[ns]
#  1   sensor_00       210112 non-null  float64
#  2   sensor_01       219951 non-null  float64
#  3   sensor_02       220301 non-null  float64
#  4   sensor_03       220301 non-null  float64
#  5   sensor_04       220301 non-null  float64
#  6   sensor_05       220301 non-null  float64
#  7   sensor_06       215522 non-null  float64
#  8   sensor_07       214869 non-null  float64
#  9   sensor_08       215213 non-null  float64
#  10  sensor_09       215725 non-null  float64
#  11  sensor_10       220301 non-null  float64
#  12  sensor_11       220301 non-null  float64
#  13  sensor_12       220301 non-null  float64
#  14  sensor_13       220301 non-null  float64
#  15  sensor_14       220299 non-null  float64
# ...

# %%
df.describe()
# Out:
#            sensor_00      sensor_01      sensor_02      sensor_03  \
# count  210112.000000  219951.000000  220301.000000  220301.000000
# mean        2.372221      47.591611      50.867392      43.752481
# std         0.412227       3.296666       3.666820       2.418887
# min         0.000000       0.000000      33.159720      31.640620
# 25%         2.438831      46.310760      50.390620      42.838539
# 50%         2.456539      48.133678      51.649300      44.227428
# 75%         2.499826      49.479160      52.777770      45.312500
# max         2.549016      56.727430      56.032990      48.220490
#
#            sensor_04      sensor_05      sensor_06      sensor_07  \
# count  220301.000000  220301.000000  215522.000000  214869.000000
# mean      590.673936      73.396414      13.501537      15.843152
# std       144.023912      17.298247       2.163736       2.201155
# min         2.798032       0.000000       0.014468       0.000000
# ...

# %% [markdown]
# ### Replace null values with mean values of columns from dataset

# %%
df.isnull().sum()
# Out:
# timestamp              0
# sensor_00          10208
# sensor_01            369
# sensor_02             19
# sensor_03             19
# sensor_04             19
# sensor_05             19
# sensor_06           4798
# sensor_07           5451
# sensor_08           5107
# sensor_09           4595
# sensor_10             19
# sensor_11             19
# sensor_12             19
# sensor_13             19
# sensor_14             21
# sensor_15         220320
# sensor_16             31
# sensor_17             46
# sensor_18             46
# sensor_19             16
# sensor_20             16
# sensor_21             16
# sensor_22             41
# sensor_23             16
# sensor_24             16
# sensor_25             36
# sensor_26             20
# sensor_27             16
# sensor_28             16
# sensor_29             72
# sensor_30            261
# sensor_31             16
# sensor_32             68
# sensor_33             16
# sensor_34             16
# sensor_35             16
# ...

# %%
# As all values in sensor_15 are null drop the column
df.drop('sensor_15',axis=1, inplace=True)

# %%
for i in df.columns:
    if df[i].isnull().sum()!=0:
        df[i].fillna(np.mean(df[i]),inplace=True)
df.isnull().sum()
# Out:
# timestamp         0
# sensor_00         0
# sensor_01         0
# sensor_02         0
# sensor_03         0
# sensor_04         0
# sensor_05         0
# sensor_06         0
# sensor_07         0
# sensor_08         0
# sensor_09         0
# sensor_10         0
# sensor_11         0
# sensor_12         0
# sensor_13         0
# sensor_14         0
# sensor_16         0
# sensor_17         0
# sensor_18         0
# sensor_19         0
# sensor_20         0
# sensor_21         0
# sensor_22         0
# sensor_23         0
# sensor_24         0
# sensor_25         0
# sensor_26         0
# sensor_27         0
# sensor_28         0
# sensor_29         0
# sensor_30         0
# sensor_31         0
# sensor_32         0
# sensor_33         0
# sensor_34         0
# sensor_35         0
# sensor_36         0
# sensor_37         0
# sensor_38         0
# sensor_39         0
# sensor_40         0
# sensor_41         0
# sensor_42         0
# sensor_43         0
# sensor_44         0
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Ploting distplot using seaborn library for visually identifying outlier as well as distribution of data

# %%
sns.distplot(df['sensor_01'])
# Out:
# C:\Users\Rushik\anaconda3\envs\learning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sensor_01', ylabel='Density'>

# %% [markdown]
# ### Plotting displot for each feature

# %%
plt.figure(figsize=(20,20))
j=0
for i in df.columns[1:]:
    j=j+1
    if j>25:
        break
    plt.subplot(5,5,j)
    sns.distplot(df[i])
# Out:
# C:\Users\Rushik\anaconda3\envs\learning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Rushik\anaconda3\envs\learning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(20,20))
j=0
for i in df.columns[26:]:
    j=j+1
    if j>25:
        break
    plt.subplot(5,5,j)
    sns.distplot(df[i])
# Out:
# C:\Users\Rushik\anaconda3\envs\learning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Rushik\anaconda3\envs\learning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Plotting boxplot for each feature for visualizingsummary about data like mean as well as outlier

# %%
plt.figure(figsize=(20,20))
j=0
for i in df.columns[1:]:
    j=j+1
    if j>25:
        break
    plt.subplot(5,5,j)
    plt.boxplot(df[i])
    plt.title("{}".format(df.columns[j]))

# %%
plt.figure(figsize=(20,20))
j=25
k=0
for i in df.columns[26:]:
    j=j+1
    k=k+1
    if j>50:
        break
    plt.subplot(5,5,k)
    plt.boxplot(df[i])
    plt.title("{}".format(df.columns[j]))

# %% [markdown]
# # Anomaly Detection

# %% [markdown]
# ### Importing PCA for dimensionality reduction

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df2=df.iloc[:,1:-1]

# %%
names=df2.columns
x = df[names]
scaler = StandardScaler()
scaler.fit(x)
# Out:
# StandardScaler()

# %%
scaled_data=scaler.transform(x)

# %%
scaled_data.shape
# Out:
# (220320, 51)

# %%
pca=PCA()
pca.fit(scaled_data)
features = range(pca.n_components_)
_ = plt.figure(figsize=(15, 5))
_ = plt.bar(features, pca.explained_variance_)
_ = plt.xlabel('PCA feature')
_ = plt.ylabel('Variance')
_ = plt.xticks(features)
_ = plt.title("Importance of the Principal Components based on inertia")
plt.show()

# %%
# Taking components equals to 3

# %%
pca=PCA(n_components=3)
pca.fit(scaled_data)
# Out:
# PCA(n_components=3)

# %%
x_pca=pca.transform(scaled_data)

# %%
x_pca.shape
x_pca
pcDf = pd.DataFrame(data = x_pca, columns = ['pc1','pc2','pc3'])
pcDf.max()
# Out:
# pc1    13.346382
# pc2    19.277153
# pc3    76.776913
# dtype: float64

# %% [markdown]
# # Inter-Quartile Range

# %%
df_outlier=df

# %%
q1_pc1, q3_pc1 =pcDf['pc1'].quantile([0.25, 0.75])
iqr_pc1 = q3_pc1 - q1_pc1
# Calculate upper and lower bounds for outlier for pc1
lower_pc1 = q1_pc1 - (1.5*iqr_pc1)
x_lower_pc1=q1_pc1 - (3*iqr_pc1) #extreme lower bound
upper_pc1 = q3_pc1 + (1.5*iqr_pc1)
x_upper_pc1= q3_pc1 + (3*iqr_pc1) #extreme upper bound
# Filter out the outliers from the pc1
df_outlier['anomaly_pc1'] = ((pcDf['pc1']>upper_pc1) | (pcDf['pc1']<lower_pc1)).astype('int')
#anomaly
anomaly = df[df_outlier['anomaly_pc1'] == 1]
#plotting outlier/anomaly with original data
_ = plt.figure(figsize=(18,6))
_ = plt.plot_date(df['timestamp'], df['sensor_00'], color='blue', label='Normal')
_ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_00'], linestyle='none', marker='.', color='red',label='Anomaly')
_ = plt.xlabel('Date and Time')
_ = plt.ylabel('sensor_00 Reading')
_ = plt.title('sensor_00 Anomalies')
_ = plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rushik\AppData\Local\Temp\ipykernel_14696\1458097458.py:15: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   _ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_00'], linestyle='none', marker='.', color='red',label='Anomaly')

# %% [markdown]
# ### Taking extreme upper and lower bound. Therefore taking extreme outliers

# %%
df_outlier['anomaly_pc1'] = ((pcDf['pc1']>x_upper_pc1) | (pcDf['pc1']<x_lower_pc1)).astype('int')
anomaly = df[df_outlier['anomaly_pc1'] == 1]
_ = plt.figure(figsize=(18,6))
_ = plt.plot_date(df['timestamp'], df['sensor_00'], color='blue', label='Normal')
_ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_00'], linestyle='none', marker='.', color='red',label='Anomaly')
_ = plt.xlabel('Date and Time')
_ = plt.ylabel('sensor_00 Reading')
_ = plt.title('sensor_00 Anomalies')
_ = plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rushik\AppData\Local\Temp\ipykernel_14696\234684381.py:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   _ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_00'], linestyle='none', marker='.', color='red',label='Anomaly')

# %% [markdown]
# ### Similarly plotting with other features

# %%
_ = plt.figure(figsize=(18,6))
_ = plt.plot_date(df['timestamp'], df['sensor_01'], color='blue', label='Normal')
_ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_01'], linestyle='none', marker='.', color='red',label='Anomaly')
_ = plt.xlabel('Date and Time')
_ = plt.ylabel('sensor_01 Reading')
_ = plt.title('sensor_01 Anomalies')
_ = plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rushik\AppData\Local\Temp\ipykernel_14696\1435538344.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   _ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_01'], linestyle='none', marker='.', color='red',label='Anomaly')

# %%
_ = plt.figure(figsize=(18,6))
_ = plt.plot_date(df['timestamp'], df['sensor_02'], color='blue', label='Normal')
_ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_02'], linestyle='none', marker='.', color='red',label='Anomaly')
_ = plt.xlabel('Date and Time')
_ = plt.ylabel('sensor_02 Reading')
_ = plt.title('sensor_02 Anomalies')
_ = plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rushik\AppData\Local\Temp\ipykernel_14696\621590035.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   _ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_02'], linestyle='none', marker='.', color='red',label='Anomaly')

# %% [markdown]
# # DBSCAN

# %%
dbscan_outlier=df

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN()

# %%
pred = dbscan.fit_predict(pcDf)

# %%
dbscan_outlier['anomaly_index']=(pred==-1).astype(int)

# %%
anomaly = df[dbscan_outlier['anomaly_index'] == 1]
#plotting outlier/anomaly with original data
_ = plt.figure(figsize=(18,6))
_ = plt.plot_date(df['timestamp'], df['sensor_00'], color='blue', label='Normal')
_ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_00'], linestyle='none', marker='.', color='red',label='Anomaly')
_ = plt.xlabel('Date and Time')
_ = plt.ylabel('sensor_00 Reading')
_ = plt.title('sensor_00 Anomalies')
_ = plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rushik\AppData\Local\Temp\ipykernel_14696\2486356128.py:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   _ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_00'], linestyle='none', marker='.', color='red',label='Anomaly')

# %%
anomaly = df[dbscan_outlier['anomaly_index'] == 1]
#plotting outlier/anomaly with original data
_ = plt.figure(figsize=(18,6))
_ = plt.plot_date(df['timestamp'], df['sensor_01'], color='blue', label='Normal')
_ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_01'], linestyle='none', marker='.', color='red',label='Anomaly')
_ = plt.xlabel('Date and Time')
_ = plt.ylabel('sensor_01 Reading')
_ = plt.title('sensor_01 Anomalies')
_ = plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rushik\AppData\Local\Temp\ipykernel_14696\3941923056.py:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   _ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_01'], linestyle='none', marker='.', color='red',label='Anomaly')

# %%
anomaly = df[dbscan_outlier['anomaly_index'] == 1]
#plotting outlier/anomaly with original data
_ = plt.figure(figsize=(18,6))
_ = plt.plot_date(df['timestamp'], df['sensor_02'], color='blue', label='Normal')
_ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_02'], linestyle='none', marker='.', color='red',label='Anomaly')
_ = plt.xlabel('Date and Time')
_ = plt.ylabel('sensor_02 Reading')
_ = plt.title('sensor_02 Anomalies')
_ = plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rushik\AppData\Local\Temp\ipykernel_14696\586752943.py:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   _ = plt.plot_date(anomaly['timestamp'],anomaly['sensor_02'], linestyle='none', marker='.', color='red',label='Anomaly')
